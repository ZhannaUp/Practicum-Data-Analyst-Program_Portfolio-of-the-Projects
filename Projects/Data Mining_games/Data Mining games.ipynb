# %% [markdown]
# <div class="alert alert-block alert-info">
# <font size="5">
# <center><b>ПОИСК ЗАКОНОМЕРНОСТЕЙ В ДАННЫХ О ПРОДАЖЕ ИГР</b></center>
# </font>
#     </div>

# %% [markdown]
# <span class="mark">Описание проекта</span>\
#     Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#     Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#     В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# <span class="mark">Инструкция по выполнению проекта</span>
#
# <font color='saddlebrown'>**Шаг 1. Откройте файл с данными и изучите общую информацию**</font>
#
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# <font color='saddlebrown'>**Шаг 2. Подготовьте данные**</font>
#
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости:
#   * Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#   * Опишите причины, которые могли привести к пропускам;
#   * Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# <font color='saddlebrown'>**Шаг 3. Проведите исследовательский анализ данных**</font>
#
# * Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# * Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# * Не учитывайте в работе данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# * Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# * Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# * Соотнесите выводы с продажами игр на других платформах.
# * Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# <font color='saddlebrown'>**Шаг 4. Составьте портрет пользователя каждого региона**</font>
#
# * Определите для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# * Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# <font color='saddlebrown'>**Шаг 5. Проверьте гипотезы**</font>
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# * Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
# * Как вы сформулировали нулевую и альтернативную гипотезы;
# * Какой критерий применили для проверки гипотез и почему.
#
# <font color='saddlebrown'>**Шаг 6. Напишите общий вывод**</font>
#
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# <span class="mark">Описание данных</span>
#
# `Name` — название игры\
# `Platform` — платформа\
# `Year_of_Release` — год выпуска\
# `Genre` — жанр игры\
# `NA_sales` — продажи в Северной Америке (миллионы проданных копий)\
# `EU_sales` — продажи в Европе (миллионы проданных копий)\
# `JP_sales` — продажи в Японии (миллионы проданных копий)\
# `Other_sales` — продажи в других странах (миллионы проданных копий)\
# `Critic_Score` — оценка критиков (максимум 100)\
# `User_Score` — оценка пользователей (максимум 10)\
# `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).\
# Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.\
#
# *Данные за 2016 год могут быть неполными.*

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Подключим библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as pylab
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import math
import seaborn as sns
from scipy import stats as st

# %% [markdown]
# Откроем файл `/datasets/games.csv`, сохраним датафрейм в переменную `games`

# %%
games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %% [markdown]
# Выведим первые 30 строк датафрейма `games`

# %%
games.head(100)
# Out:
#                                       Name Platform  Year_of_Release  \
# 0                               Wii Sports      Wii           2006.0
# 1                        Super Mario Bros.      NES           1985.0
# 2                           Mario Kart Wii      Wii           2008.0
# 3                        Wii Sports Resort      Wii           2009.0
# 4                 Pokemon Red/Pokemon Blue       GB           1996.0
# ..                                     ...      ...              ...
# 95  Crash Bandicoot 2: Cortex Strikes Back       PS           1997.0
# 96     Super Smash Bros. for Wii U and 3DS      3DS           2014.0
# 97                    Super Mario Galaxy 2      Wii           2010.0
# 98                     Super Mario Bros. 2      NES           1988.0
# 99               Call of Duty: Black Ops 3     XOne           2015.0
#
#            Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 0         Sports     41.36     28.96      3.77         8.45          76.0
# 1       Platform     29.08      3.58      6.81         0.77           NaN
# 2         Racing     15.68     12.76      3.79         3.29          82.0
# 3         Sports     15.61     10.93      3.28         2.95          80.0
# 4   Role-Playing     11.27      8.89     10.22         1.00           NaN
# ..           ...       ...       ...       ...          ...           ...
# 95      Platform      3.78      2.17      1.31         0.31           NaN
# 96      Fighting      3.27      1.37      2.43         0.48           NaN
# 97      Platform      3.56      2.35      0.98         0.62          97.0
# 98      Platform      5.39      1.18      0.70         0.19           NaN
# 99       Shooter      4.59      2.11      0.01         0.68           NaN
#
#    User_Score Rating
# 0           8      E
# 1         NaN    NaN
# 2         8.3      E
# 3           8      E
# 4         NaN    NaN
# ..        ...    ...
# 95        NaN    NaN
# 96        NaN    NaN
# 97        9.1      E
# 98        NaN    NaN
# 99        NaN    NaN
#
# [100 rows x 11 columns]

# %% [markdown]
# Выведим основную информацию для датафрейма `games` с помощью метода `info()`

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Посмотрим сводную статистику для датафрейма `games` с помощью метода `describe()`

# %%
games.describe().T
# Out:
#                    count         mean        std     min     25%      50%  \
# Year_of_Release  16446.0  2006.484616   5.877050  1980.0  2003.0  2007.00
# NA_sales         16715.0     0.263377   0.813604     0.0     0.0     0.08
# EU_sales         16715.0     0.145060   0.503339     0.0     0.0     0.02
# JP_sales         16715.0     0.077617   0.308853     0.0     0.0     0.00
# Other_sales      16715.0     0.047342   0.186731     0.0     0.0     0.01
# Critic_Score      8137.0    68.967679  13.938165    13.0    60.0    71.00
#
#                      75%      max
# Year_of_Release  2010.00  2016.00
# NA_sales            0.24    41.36
# EU_sales            0.11    28.96
# JP_sales            0.04    10.22
# Other_sales         0.03    10.57
# Critic_Score       79.00    98.00

# %% [markdown]
# Проверим наличие пропусков в каждом столбце(%)

# %%
pd.DataFrame(round(games.isna().mean()*100,)).style.background_gradient('BuPu')
# Out:
# <style type="text/css">
# #T_0a6a2_row0_col0, #T_0a6a2_row1_col0, #T_0a6a2_row3_col0, #T_0a6a2_row4_col0, #T_0a6a2_row5_col0, #T_0a6a2_row6_col0, #T_0a6a2_row7_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_0a6a2_row2_col0 {
#   background-color: #f0f7fa;
#   color: #000000;
# }
# #T_0a6a2_row8_col0 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_0a6a2_row9_col0, #T_0a6a2_row10_col0 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0a6a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a6a2_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a6a2_level0_row0" class="row_heading level0 row0" >Name</th>
#       <td id="T_0a6a2_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row1" class="row_heading level0 row1" >Platform</th>
#       <td id="T_0a6a2_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row2" class="row_heading level0 row2" >Year_of_Release</th>
#       <td id="T_0a6a2_row2_col0" class="data row2 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row3" class="row_heading level0 row3" >Genre</th>
#       <td id="T_0a6a2_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row4" class="row_heading level0 row4" >NA_sales</th>
#       <td id="T_0a6a2_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row5" class="row_heading level0 row5" >EU_sales</th>
#       <td id="T_0a6a2_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row6" class="row_heading level0 row6" >JP_sales</th>
#       <td id="T_0a6a2_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row7" class="row_heading level0 row7" >Other_sales</th>
#       <td id="T_0a6a2_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row8" class="row_heading level0 row8" >Critic_Score</th>
#       <td id="T_0a6a2_row8_col0" class="data row8 col0" >51.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row9" class="row_heading level0 row9" >User_Score</th>
#       <td id="T_0a6a2_row9_col0" class="data row9 col0" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a6a2_level0_row10" class="row_heading level0 row10" >Rating</th>
#       <td id="T_0a6a2_row10_col0" class="data row10 col0" >40.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Посмотрим пропущенные значения бары

# %%
def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16, color = 'SlateGray')
            .set_title('Пропуски в датасете' + "\n", fontsize = 22, color = 'dimgray')    
        );    
    except:
        print('пропусков не осталось')

# %%
pass_value_barh(games)

# %% [markdown]
#  С помощью метода `hist()` выведим гистограммы для всех <span class="girk">столбцов.</span>

# %%
params = {'axes.titlesize':'20',
          'xtick.labelsize':'20',
          'ytick.labelsize':'20'}

games.hist(figsize=(15, 10), color='SlateGray')
plt.show()

# %% [markdown]
# <font color='saddlebrown'>**ВЫВОД**:</font>
# <div style="border:solid saddlebrown 2px; padding: 20px">
#
# В исходном датасете 16715 строк и 11 столбцов.
# После того, как изучили датасет, выявили следующие первичные отклонения:
# 1) `Year_of_Release`- не соответствует тип колонки float64, 2% пустых значений \
# 2) `Critic_Score`- <font color='red'>**51%**</font> пустых значений,не соответствует тип колонки float64 \
# 3) `User_Score` - <font color='red'>**40%**</font> пустых значений\
# 4) `Rating`- <font color='red'>**40%**</font> пустых значений\
# 5) Названия столбцов указаны в верхнем регистре, замена на нижний.
#
# </div>

# %% [markdown]
# ### Подготовьте данные
#
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости:
# * Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# * Опишите причины, которые могли привести к пропускам;
# * Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %% [markdown]
# #### Заменим названия столбцов к нижнему регистру

# %%
games.columns = games.columns.str.lower()
games.head(3)
# Out:
#                 name platform  year_of_release     genre  na_sales  eu_sales  \
# 0         Wii Sports      Wii           2006.0    Sports     41.36     28.96
# 1  Super Mario Bros.      NES           1985.0  Platform     29.08      3.58
# 2     Mario Kart Wii      Wii           2008.0    Racing     15.68     12.76
#
#    jp_sales  other_sales  critic_score user_score rating
# 0      3.77         8.45          76.0          8      E
# 1      6.81         0.77           NaN        NaN    NaN
# 2      3.79         3.29          82.0        8.3      E

# %% [markdown]
# #### Преобразуем столбцы к новому типу данных, обработаем пропуски, проверим дубликаты

# %% [markdown]
# Проверим типы данных

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Проверим наличие пустых значений по всем столбцам с помощью метода `isna()`

# %%
games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Проверим дубликаты

# %%
games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### `name`

# %% [markdown]
# Пустые значения удалим с помощью метода `.dropna()`, тк нельзя ничем их заменить и усреднить, количесво 2.

# %%
games = games.dropna(subset = ['name'])

# %% [markdown]
# Проверяем пустые значения

# %%
games['name'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### `year_of_release`

# %% [markdown]
# Перед заменой типа данных в столбце Year_of_Release обработаем пустые значения в количестве 269 или 2%

# %% [markdown]
# Заменим пропуски на год выпуска при совпадении названия игры, чтобы восстановить часть статистики.

# %%
for i in games['name'].unique(): 
    games.loc[(games['name'] == i) & (games['year_of_release'].isna()), 'year_of_release'] = \
    games.loc[(games['name'] == i), 'year_of_release'].max()

# %% [markdown]
# Проверяем пустые значения

# %%
games['year_of_release'].isna().sum()
# Out:
# 146

# %% [markdown]
# Пустые значения удалим с помощью метода `.dropna()`, тк нельзя ничем их заменить и усреднить, количесво незначительное.

# %%
games = games.dropna(subset = ['year_of_release'])

# %% [markdown]
# Тип данных заменяем с помощью метода `.astype('Int64')`, чтобы мы смогли определить год выпуска игр.

# %%
games['year_of_release'] = games['year_of_release'].astype('Int64')

# %%
games['year_of_release'].head(3)
# Out:
# 0    2006
# 1    1985
# 2    2008
# Name: year_of_release, dtype: Int64

# %% [markdown]
# Проверяем пустые значения

# %%
games['year_of_release'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### `critic_score`

# %% [markdown]
# Пропусков 8578 или 51%. Удалить нельзя, заменить медианным значение тоже нельзя

# %% [markdown]
# Изучим к какой игре 'name' относится основная масса пропусков в параметре 'critic_score', после взгляда на таблицу все станет ясно, что делать дальше с пропусками.

# %%
x = (
        games
         .value_counts('name')
        
         .to_frame()
         .rename(columns = {0:'count'})
    )



y = (
        games[games['critic_score'].isna()]
                .value_counts('name')).to_frame().rename(columns = {0:'count_gap'}
    )


z = x.join(y, how = 'outer').reset_index().sort_values(by = 'count', ascending = False).head(25)
z.style.format("{:,.0f}", subset = ['count_gap', 'count'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_2fb42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fb42_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2fb42_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_2fb42_level0_col2" class="col_heading level0 col2" >count_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fb42_level0_row0" class="row_heading level0 row0" >6640</th>
#       <td id="T_2fb42_row0_col0" class="data row0 col0" >Need for Speed: Most Wanted</td>
#       <td id="T_2fb42_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_2fb42_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row1" class="row_heading level0 row1" >2915</th>
#       <td id="T_2fb42_row1_col0" class="data row1 col0" >FIFA 14</td>
#       <td id="T_2fb42_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_2fb42_row1_col2" class="data row1 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row2" class="row_heading level0 row2" >5081</th>
#       <td id="T_2fb42_row2_col0" class="data row2 col0" >LEGO Marvel Super Heroes</td>
#       <td id="T_2fb42_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_2fb42_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row3" class="row_heading level0 row3" >5405</th>
#       <td id="T_2fb42_row3_col0" class="data row3 col0" >Madden NFL 07</td>
#       <td id="T_2fb42_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_2fb42_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row4" class="row_heading level0 row4" >7703</th>
#       <td id="T_2fb42_row4_col0" class="data row4 col0" >Ratatouille</td>
#       <td id="T_2fb42_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_2fb42_row4_col2" class="data row4 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row5" class="row_heading level0 row5" >5073</th>
#       <td id="T_2fb42_row5_col0" class="data row5 col0" >LEGO Harry Potter: Years 5-7</td>
#       <td id="T_2fb42_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_2fb42_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row6" class="row_heading level0 row6" >5094</th>
#       <td id="T_2fb42_row6_col0" class="data row6 col0" >LEGO The Hobbit</td>
#       <td id="T_2fb42_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_2fb42_row6_col2" class="data row6 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row7" class="row_heading level0 row7" >2932</th>
#       <td id="T_2fb42_row7_col0" class="data row7 col0" >FIFA Soccer 13</td>
#       <td id="T_2fb42_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_2fb42_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row8" class="row_heading level0 row8" >1290</th>
#       <td id="T_2fb42_row8_col0" class="data row8 col0" >Cars</td>
#       <td id="T_2fb42_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_2fb42_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row9" class="row_heading level0 row9" >9660</th>
#       <td id="T_2fb42_row9_col0" class="data row9 col0" >Terraria</td>
#       <td id="T_2fb42_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_2fb42_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row10" class="row_heading level0 row10" >2916</th>
#       <td id="T_2fb42_row10_col0" class="data row10 col0" >FIFA 15</td>
#       <td id="T_2fb42_row10_col1" class="data row10 col1" >8</td>
#       <td id="T_2fb42_row10_col2" class="data row10 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row11" class="row_heading level0 row11" >5090</th>
#       <td id="T_2fb42_row11_col0" class="data row11 col0" >LEGO Star Wars II: The Original Trilogy</td>
#       <td id="T_2fb42_row11_col1" class="data row11 col1" >8</td>
#       <td id="T_2fb42_row11_col2" class="data row11 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row12" class="row_heading level0 row12" >341</th>
#       <td id="T_2fb42_row12_col0" class="data row12 col0" >Angry Birds Star Wars</td>
#       <td id="T_2fb42_row12_col1" class="data row12 col1" >8</td>
#       <td id="T_2fb42_row12_col2" class="data row12 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row13" class="row_heading level0 row13" >9881</th>
#       <td id="T_2fb42_row13_col0" class="data row13 col0" >The LEGO Movie Videogame</td>
#       <td id="T_2fb42_row13_col1" class="data row13 col1" >8</td>
#       <td id="T_2fb42_row13_col2" class="data row13 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row14" class="row_heading level0 row14" >5078</th>
#       <td id="T_2fb42_row14_col0" class="data row14 col0" >LEGO Jurassic World</td>
#       <td id="T_2fb42_row14_col1" class="data row14 col1" >8</td>
#       <td id="T_2fb42_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row15" class="row_heading level0 row15" >5406</th>
#       <td id="T_2fb42_row15_col0" class="data row15 col0" >Madden NFL 08</td>
#       <td id="T_2fb42_row15_col1" class="data row15 col1" >8</td>
#       <td id="T_2fb42_row15_col2" class="data row15 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row16" class="row_heading level0 row16" >6005</th>
#       <td id="T_2fb42_row16_col0" class="data row16 col0" >Monopoly</td>
#       <td id="T_2fb42_row16_col1" class="data row16 col1" >8</td>
#       <td id="T_2fb42_row16_col2" class="data row16 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row17" class="row_heading level0 row17" >5147</th>
#       <td id="T_2fb42_row17_col0" class="data row17 col0" >Lego Batman 3: Beyond Gotham</td>
#       <td id="T_2fb42_row17_col1" class="data row17 col1" >8</td>
#       <td id="T_2fb42_row17_col2" class="data row17 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row18" class="row_heading level0 row18" >5091</th>
#       <td id="T_2fb42_row18_col0" class="data row18 col0" >LEGO Star Wars III: The Clone Wars</td>
#       <td id="T_2fb42_row18_col1" class="data row18 col1" >7</td>
#       <td id="T_2fb42_row18_col2" class="data row18 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row19" class="row_heading level0 row19" >5095</th>
#       <td id="T_2fb42_row19_col0" class="data row19 col0" >LEGO The Lord of the Rings</td>
#       <td id="T_2fb42_row19_col1" class="data row19 col1" >7</td>
#       <td id="T_2fb42_row19_col2" class="data row19 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row20" class="row_heading level0 row20" >9049</th>
#       <td id="T_2fb42_row20_col0" class="data row20 col0" >Star Wars The Clone Wars: Republic Heroes</td>
#       <td id="T_2fb42_row20_col1" class="data row20 col1" >7</td>
#       <td id="T_2fb42_row20_col2" class="data row20 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row21" class="row_heading level0 row21" >10010</th>
#       <td id="T_2fb42_row21_col0" class="data row21 col0" >The Sims 2</td>
#       <td id="T_2fb42_row21_col1" class="data row21 col1" >7</td>
#       <td id="T_2fb42_row21_col2" class="data row21 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row22" class="row_heading level0 row22" >2914</th>
#       <td id="T_2fb42_row22_col0" class="data row22 col0" >FIFA 12</td>
#       <td id="T_2fb42_row22_col1" class="data row22 col1" >7</td>
#       <td id="T_2fb42_row22_col2" class="data row22 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row23" class="row_heading level0 row23" >7474</th>
#       <td id="T_2fb42_row23_col0" class="data row23 col0" >Pro Evolution Soccer 2012</td>
#       <td id="T_2fb42_row23_col1" class="data row23 col1" >7</td>
#       <td id="T_2fb42_row23_col2" class="data row23 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2fb42_level0_row24" class="row_heading level0 row24" >8715</th>
#       <td id="T_2fb42_row24_col0"

# %% [markdown]
# Тип данных заменяем с помощью метода `.astype('Int64')`, но сначала nan заменяем на "заглушку" -999

# %%
games['critic_score'] = games['critic_score'].fillna(-999).astype('Int64')
games['critic_score'].head(3)
# Out:
# 0      76
# 1    -999
# 2      82
# Name: critic_score, dtype: Int64

# %% [markdown]
# Проверяем пустые значения

# %%
games['critic_score'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### `user_score`

# %% [markdown]
# Пропусков 6701 или 40%. Удалить нельзя, заменить медианным значение тоже нельзя

# %% [markdown]
# Обратим внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Разберем это значение и опишим, как его обработать

# %% [markdown]
# TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований.

# %% [markdown]
# Тип данных заменяем с помощью метода `.astype('float')`, но сначала nan и tbd заменяем на "заглушку" -999

# %%
games.loc[games['user_score'] == 'tbd', 'user_score'] = -999

# %%
games['user_score'] = games['user_score'].fillna(-999).astype('float')

# %%
games['user_score'].head(10)
# Out:
# 0      8.0
# 1   -999.0
# 2      8.3
# 3      8.0
# 4   -999.0
# 5   -999.0
# 6      8.5
# 7      6.6
# 8      8.4
# 9   -999.0
# Name: user_score, dtype: float64

# %% [markdown]
# ##### `rating `

# %% [markdown]
# Пропусков 6766 или 40%. Удалить нельзя, тк это сильно исказить статистику, заменим nan на unknown и это будет дополнительным критерием для фильтрации.

# %%
games['rating'] = games['rating'].fillna('unknown')

# %%
games['rating'].head(10)
# Out:
# 0          E
# 1    unknown
# 2          E
# 3          E
# 4    unknown
# 5    unknown
# 6          E
# 7          E
# 8          E
# 9    unknown
# Name: rating, dtype: object

# %% [markdown]
# Проверим выбросы

# %%
games.rating.value_counts().to_frame()
# Out:
#          rating
# unknown    6699
# E          3958
# T          2930
# M          1554
# E10+       1412
# EC            8
# K-A           3
# RP            2
# AO            1

# %% [markdown]
# Проверяем корректировки

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16567 non-null  object
#  1   platform         16567 non-null  object
#  2   year_of_release  16567 non-null  Int64
#  3   genre            16567 non-null  object
#  4   na_sales         16567 non-null  float64
#  5   eu_sales         16567 non-null  float64
#  6   jp_sales         16567 non-null  float64
#  7   other_sales      16567 non-null  float64
#  8   critic_score     16567 non-null  Int64
#  9   user_score       16567 non-null  float64
#  10  rating           16567 non-null  object
# dtypes: Int64(2), float64(5), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Проверяем корректировки

# %%
games.isna().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# Проверим полностью таблицу

# %%
games.sample(50)
# Out:
#                                                     name platform  \
# 5103                                             Quake 4     X360
# 7881                      Princess Maker: Yumemiru Yosei       PS
# 5047                   Dancing with the Stars: We Dance!      Wii
# 11585                            Assassin's Creed: Rogue       PC
# 7672                              Farming Simulator 2015     XOne
# 11978                 Burnout Paradise: The Ultimate Box      PS3
# 3546                                      Rune Factory 4      3DS
# 13790                                            Gal*Gun     X360
# 9571   Pokémon: For Ho-Oh the Bells Toll!: Game Boy A...      GBA
# 9140                                Metal Slug Anthology      Wii
# 4638                                            Vanquish     X360
# 13868                             Headhunter: Redemption      PS2
# 2691                                    Final Fantasy II      NES
# 12534                                    Project Setsuna      PS4
# 1637                                  Mario Power Tennis       GC
# 3798      Tom Clancy's Ghost Recon Advanced Warfighter 2      PSP
# 10378                             Total Immersion Racing      PS2
# 9710                            The King of Fighters '94       NG
# 13312               Detective Conan: Marionette Symphony      3DS
# 403    English Training: Have Fun Improving Your Skills!       DS
# 7726                                            Yoga Wii      Wii
# 9405          Jikkyou Powerful Pro Yakyuu 2011 Ketteiban      PSP
# 10330                                          Aqua Aqua      PS2
# 9819      Transformers: War for Cybertron -- Decepticons       DS
# 7790                                      Fighter Within     XOne
# 7045                                        Tales of VS.      PSP
# 1049                           Call of Duty: Black Ops 3     X360
# 11781   Formula One World Championship: Beyond the Limit      SCD
# 980             Professor Layton and the Mask of Miracle      3DS
# 12569                              Coded Arms: Contagion      PSP
# 3246                                           Halloween     2600
# 13519               Disney's Donald Duck: Goin' Quackers       GC
# 3538                                     Disney Universe     X360
# 8691                          He-Man: Power of Grayskull      GBA
# 9456                         Chuck E. Cheese's Game Room       DS
# 15369                                    Guess the Logos       XB
# 6556                                       Desert Falcon     2600
# 12914                                 Dynasty Warriors 5       XB
# 15876                                  Storm Lover 2nd V      PSV
# 12897                                   Sega Soccer Slam       XB
# 9013            Okaeri! Chibi-Robo! Happy Richie Oosouji       DS
# 2349                                   Seiken Densetsu 3     SNES
# 2677                                             FIFA 12      Wii
# 10536                                         Shellshock       PS
# 15989                                Antz Extreme Racing       XB
# 6476                        LEGO Harry Potter: Years 5-7      PSP
# 16038  Katekyoo Hitman Reborn! DS: Mafia Daishuugou B...       DS
# 5640                                                Prey     X360
# 12214        Nobunaga no Yabou: Tendou with Power-Up Kit      PS3
# 661                                        Madden NFL 11      PS3
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 5103              2005       Shooter      0.32      0.02      0.00
# 7881              1997      Strategy      0.00      0.00      0.18
# 5047              2008          Misc      0.35      0.00      0.00
# 11585             2015        Action      0.05      0.02      0.00
# 7672              2015    Simulation      0.10      0.08      0.00
# 11978             2009        Racing      0.00      0.05      0.01
# 3546              2012  Role-Playing      0.32      0.00      0.21
# 13790             2011       Shooter      0.00      0.00      0.04
# 9571              2004          Misc      0.09      0.03      0.00
# 9140              2006       Shooter      0.12      0.01      0.00
# 4638              2010       Shooter      0.19      0.16      0.03
# 13868             2004        Action      0.02      0.01      0.00
# 2691              1988  Role-Playing      0.00      0.00      0.76
# 12534             2016  Role-Playing      0.00      0.00      0.06
# 1637              2004        Sports      0.58      0.16      0.46
# 3798              2007       Shooter      0.35      0.09      0.00
# 10378             2002        Racing      0.05      0.04      0.00
# 9710              1994      Fighting      0.00      0.00      0.12
# 13312             2013     Adventure      0.00      0.00      0.05
# 403               2006          Misc      0.00      0.99      2.32
# 7726              2009        Sports      0.14      0.04      0.00
# 9405              2011        Sports      0.00      0.00      0.13
# 10330             2000        Puzzle      0.05      0.04      0.00
# 9819              2010        Action      0.11      0.01      0.00
# 7790              2013      Fighting      0.11      0.07      0.00
# 7045              2009      Fighting      0.00      0.00      0.23
# 1049              2015       Shooter      1.14      0.40      0.00
# 11781             1994        Racing      0.00      0.00      0.07
# 980               2011        Puzzle      0.32      0.97      0.36
# 12569             2007       Shooter      0.05      0.00      0.00
# 3246              1982        Action      0.58      0.03      0.00
# 13519             2002      Platform      0.03      0.01      0.00
# 3538              2011        Action      0.37      0.14      0.00
# 8691              2002        Action      0.11      0.04      0.00
# 9456              2010          Misc      0.12      0.00      0.00
# 15369             2004        Puzzle      0.02      0.00      0.00
# 6556              1987       Shooter      0.24      0.01      0.00
# 12914             2005        Action      0.04      0.01      0.00
# 15876             2016     Adventure      0.00      0.00      0.02
# 12897             2002        Sports      0.04      0.01      0.00
# 9013              2009     Adventure      0.00      0.00      0.14
# 2349              1995  Role-Playing      0.00      0.00      0.89
# 2677              2011        Sports      0.15      0.50      0.00
# 10536             1995        Action      0.06      0.04      0.00
# 15989             2002        Racing      0.01      0.00      0.00
# 6476              2012        Action      0.10      0.10      0.00
# 16038             2008        Action      0.00      0.00      0.02
# 5640              2006       Shooter      0.27      0.03      0.00
# 12214             2011      Strategy      0.00      0.00      0.07
# 661               2010        Sports      2.04      0.15      0.00
#
#        other_sales  critic_score  user_score   rating
# 5103          0.03            75         6.7        M
# 7881          0.01          -999      -999.0  unknown
# 5047          0.03          -999      -999.0  unknown
# 11585         0.01            74         7.5        M
# 7672          0.02          -999      -999.0  unknown
# 11978         0.01          -999      -999.0  unknown
# 3546          0.03            78         8.1     E10+
# 13790         0.00          -999      -999.0  unknown
# 9571          0.00          -999      -999.0  unknown
# 9140          0.01            73         8.0        T
# 4638          0.04            84         8.4        M
# 13868         0.00            62         6.7        M
# 2691          0.00          -999      -999.0  unknown
# 12534         0.00          -999      -999.0  unknown
# 1637          0.03            80         8.5        E
# 3798          0.08            61         6.4        T
# 10378         0.01            59      -999.0        E
# 9710          0.00          -999      -999.0  unknown
# 13312         0.00          -999      -999.0  unknown
# 403           0.02          -999      -999.0  unknown
# 7726          0.02          -999      -999.0  unknown
# 9405          0.00          -999      -999.0  unknown
# 10330         0.01            79      -999.0        E
# 9819          0.01          -999      -999.0  unknown
# 7790          0.02            23         3.0        T
# 7045          0.00          -999      -999.0  unknown
# 1049          0.16          -999      -999.0  unknown
# 11781         0.00          -999      -999.0  unknown
# 980           0.13          -999      -999.0  unknown
# 12569         0.01            56         6.6        T
# 3246          0.01          -999      -999.0  unknown
# 13519         0.00            61         3.0        E
# 3538          0.05            66         5.3     E10+
# 8691          0.00            50      -999.0        E
# 9456          0.01          -999      -999.0        E
# 15369         0.00          -999      -999.0  unknown
# 6556          0.00          -999      -999.0  unknown
# 12914         0.00            66         8.0        T
# 15876         0.00          -999      -999.0  unknown
# 12897         0.00            80         8.5        E
# 9013          0.00          -999      -999.0  unknown
# 2349          0.00          -999      -999.0  unknown
# 2677          0.11          -999      -999.0  unknown
# 10536         0.01          -999      -999.0  unknown
# 15989         0.00            35         8.7        E
# 6476          0.06          -999      -999.0     E10+
# 16038         0.00          -999      -999.0  unknown
# 5640          0.03            79         7.3        M
# 12214         0.00          -999      -999.0  unknown
# 661           0.20            83         6.1        E

# %% [markdown]
# Проверим количество строк и столбцов

# %%
games.shape
# Out:
# (16567, 11)

# %% [markdown]
# ##### Посчитаем суммарные продажи во всех регионах и запишим их в отдельный столбец.

# %% [markdown]
# Создадим новый столбец total_sales_regions сложив все продажи

# %%
games['total_sales_regions'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
games.head(3)
# Out:
#                 name platform  year_of_release     genre  na_sales  eu_sales  \
# 0         Wii Sports      Wii             2006    Sports     41.36     28.96
# 1  Super Mario Bros.      NES             1985  Platform     29.08      3.58
# 2     Mario Kart Wii      Wii             2008    Racing     15.68     12.76
#
#    jp_sales  other_sales  critic_score  user_score   rating  \
# 0      3.77         8.45            76         8.0        E
# 1      6.81         0.77          -999      -999.0  unknown
# 2      3.79         3.29            82         8.3        E
#
#    total_sales_regions
# 0                82.54
# 1                40.24
# 2                35.52

# %% [markdown]
# ### Исследовательский анализ

# %% [markdown]
# #### Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %% [markdown]
# Построим график, где покажем объем продаж по всем годам выпуска игр

# %%
games_year_of_release = games.groupby('year_of_release')['name'].count().plot(grid=True, kind = 'line', figsize=(15, 5), color='#5f9bd6')
plt.title('Количество выпускаемых игр по годам') # название графика
plt.xlabel('Год') # подпись оси x
plt.ylabel('Объем продаж(млн.шт)') # подпись оси y
plt.plot(games.groupby('year_of_release')['name'].count(), 'o-', label='количество релизов', alpha=1)
plt.axvspan(1980, 1991, color='grey', label='стагнация', alpha=0.3)
plt.axvspan(1991, 2008, color='green', label='рост', alpha=0.3)
plt.axvspan(2008, 2016, color='red', label='спад', alpha=0.3)
plt.grid(True)
plt.legend();
plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> Согласно графика, видно, что **с 1980 по 1990 гг** выпуск игр был незначительный и держался на уровне **до 50 игр**. **С 1990 по 2009 гг** наблюдается бум на рынке игр и количество выпускаемых игр увеличилось <font color='green'>**30 раз или на 3000%**</font>. Далее **после 2009 года** наблюдается <font color='red'>**спад**</font> выпуска игр, что может быть связано с появлением взаимозаменяемой продукции (современные мобильные устройства и приложения).

# %% [markdown]
# #### Посмотрим динамику продаж по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?  Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# Построим график динамики продаж по платформам.

# %%
platforms_year_of_release = games.pivot_table(index='platform', values='total_sales_regions', aggfunc='sum')\
                             .sort_values(by='total_sales_regions', ascending=False)\
                             .plot(grid=True, kind = 'bar', figsize=(15, 5), color='#5f9bd6')
                                                                          
plt.title('Динамика продаж по платформам (млн.шт)') # название графика
plt.xlabel('Название платформы') # подпись оси x
plt.ylabel('Объем продаж(млн.шт)') # подпись оси y
plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> На графике видно, что в топ-6 вошли такие платформы, как PS2, X360, PS3, Wii, DS и PS.

# %% [markdown]
# Выберим платформы с наибольшими суммарными продажами и построим распределение по годам. Берем первые 6 платформ, тк остальные значительно ниже по объемам продаж и создадим переменную `top_6_leaders`

# %%
# Сгруппируем платформы и продажи, отфильтруем топ-6 лидеров продаж
top_6_leaders = games.pivot_table(index='platform', values='total_sales_regions', aggfunc='sum')\
                     .sort_values(by= 'total_sales_regions', ascending = False).head(6)                                                    
# Выведим на экран 
top_6_leaders.sort_values(by= 'total_sales_regions', ascending = False).reset_index()
# Out:
#   platform  total_sales_regions
# 0      PS2              1247.16
# 1     X360               966.61
# 2      PS3               935.19
# 3      Wii               903.31
# 4       DS               804.28
# 5       PS               727.58

# %% [markdown]
# Построим таблицe "Динамика продаж всех игр за весь период"

# %%
games_years_sales = games.pivot_table(index='platform', columns= 'year_of_release', values=['total_sales_regions'],\
               aggfunc={'total_sales_regions': 'sum' }).reset_index()

cm = sns.light_palette("#5f9bd6", as_cmap=True)

games_years_sales.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_35d7e_row0_col1, #T_35d7e_row0_col2, #T_35d7e_row0_col3, #T_35d7e_row0_col4, #T_35d7e_row0_col5, #T_35d7e_row0_col7, #T_35d7e_row0_col8, #T_35d7e_row0_col10, #T_35d7e_row1_col1, #T_35d7e_row1_col2, #T_35d7e_row1_col3, #T_35d7e_row1_col15, #T_35d7e_row1_col16, #T_35d7e_row2_col1, #T_35d7e_row2_col2, #T_35d7e_row2_col3, #T_35d7e_row2_col31, #T_35d7e_row3_col1, #T_35d7e_row3_col2, #T_35d7e_row3_col3, #T_35d7e_row3_col23, #T_35d7e_row3_col28, #T_35d7e_row3_col29, #T_35d7e_row4_col1, #T_35d7e_row4_col2, #T_35d7e_row4_col3, #T_35d7e_row4_col6, #T_35d7e_row4_col34, #T_35d7e_row5_col1, #T_35d7e_row5_col2, #T_35d7e_row5_col3, #T_35d7e_row6_col1, #T_35d7e_row6_col2, #T_35d7e_row6_col3, #T_35d7e_row6_col21, #T_35d7e_row7_col1, #T_35d7e_row7_col2, #T_35d7e_row7_col3, #T_35d7e_row7_col28, #T_35d7e_row8_col1, #T_35d7e_row8_col2, #T_35d7e_row8_col3, #T_35d7e_row8_col11, #T_35d7e_row8_col12, #T_35d7e_row9_col1, #T_35d7e_row9_col2, #T_35d7e_row9_col3, #T_35d7e_row9_col13, #T_35d7e_row10_col1, #T_35d7e_row10_col2, #T_35d7e_row10_col3, #T_35d7e_row10_col23, #T_35d7e_row10_col25, #T_35d7e_row11_col1, #T_35d7e_row11_col2, #T_35d7e_row11_col3, #T_35d7e_row11_col15, #T_35d7e_row12_col1, #T_35d7e_row12_col2, #T_35d7e_row12_col3, #T_35d7e_row12_col14, #T_35d7e_row12_col17, #T_35d7e_row13_col1, #T_35d7e_row13_col2, #T_35d7e_row13_col3, #T_35d7e_row13_col6, #T_35d7e_row13_col9, #T_35d7e_row13_col27, #T_35d7e_row13_col30, #T_35d7e_row14_col1, #T_35d7e_row14_col2, #T_35d7e_row14_col3, #T_35d7e_row14_col17, #T_35d7e_row15_col1, #T_35d7e_row15_col2, #T_35d7e_row15_col3, #T_35d7e_row15_col24, #T_35d7e_row16_col1, #T_35d7e_row16_col2, #T_35d7e_row16_col3, #T_35d7e_row16_col32, #T_35d7e_row17_col1, #T_35d7e_row17_col2, #T_35d7e_row17_col3, #T_35d7e_row17_col26, #T_35d7e_row18_col1, #T_35d7e_row18_col2, #T_35d7e_row18_col3, #T_35d7e_row19_col1, #T_35d7e_row19_col2, #T_35d7e_row19_col3, #T_35d7e_row19_col33, #T_35d7e_row19_col35, #T_35d7e_row19_col36, #T_35d7e_row20_col1, #T_35d7e_row20_col2, #T_35d7e_row20_col3, #T_35d7e_row21_col1, #T_35d7e_row21_col2, #T_35d7e_row21_col3, #T_35d7e_row21_col20, #T_35d7e_row22_col1, #T_35d7e_row22_col2, #T_35d7e_row22_col3, #T_35d7e_row23_col1, #T_35d7e_row23_col2, #T_35d7e_row23_col3, #T_35d7e_row23_col18, #T_35d7e_row23_col19, #T_35d7e_row23_col20, #T_35d7e_row24_col1, #T_35d7e_row24_col2, #T_35d7e_row24_col3, #T_35d7e_row24_col16, #T_35d7e_row25_col1, #T_35d7e_row25_col2, #T_35d7e_row25_col3, #T_35d7e_row25_col20, #T_35d7e_row25_col22, #T_35d7e_row26_col1, #T_35d7e_row26_col2, #T_35d7e_row26_col3, #T_35d7e_row26_col37, #T_35d7e_row27_col1, #T_35d7e_row27_col2, #T_35d7e_row27_col3, #T_35d7e_row28_col1, #T_35d7e_row28_col2, #T_35d7e_row28_col3, #T_35d7e_row29_col1, #T_35d7e_row29_col2, #T_35d7e_row29_col3, #T_35d7e_row29_col28, #T_35d7e_row29_col29, #T_35d7e_row30_col1, #T_35d7e_row30_col2, #T_35d7e_row30_col3 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_35d7e_row0_col6, #T_35d7e_row3_col22, #T_35d7e_row8_col14, #T_35d7e_row12_col16, #T_35d7e_row22_col15, #T_35d7e_row25_col21, #T_35d7e_row26_col36, #T_35d7e_row29_col21 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_35d7e_row0_col9, #T_35d7e_row3_col19, #T_35d7e_row6_col27, #T_35d7e_row10_col22, #T_35d7e_row13_col19, #T_35d7e_row19_col34, #T_35d7e_row28_col37 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_35d7e_row0_col11, #T_35d7e_row0_col12, #T_35d7e_row0_col13, #T_35d7e_row0_col14, #T_35d7e_row0_col15, #T_35d7e_row0_col16, #T_35d7e_row0_col17, #T_35d7e_row0_col18, #T_35d7e_row0_col19, #T_35d7e_row0_col20, #T_35d7e_row0_col21, #T_35d7e_row0_col22, #T_35d7e_row0_col24, #T_35d7e_row0_col25, #T_35d7e_row0_col26, #T_35d7e_row0_col27, #T_35d7e_row0_col28, #T_35d7e_row0_col29, #T_35d7e_row0_col30, #T_35d7e_row0_col31, #T_35d7e_row0_col32, #T_35d7e_row0_col33, #T_35d7e_row0_col34, #T_35d7e_row0_col35, #T_35d7e_row0_col36, #T_35d7e_row0_col37, #T_35d7e_row1_col4, #T_35d7e_row1_col5, #T_35d7e_row1_col6, #T_35d7e_row1_col7, #T_35d7e_row1_col8, #T_35d7e_row1_col9, #T_35d7e_row1_col10, #T_35d7e_row1_col11, #T_35d7e_row1_col12, #T_35d7e_row1_col13, #T_35d7e_row1_col14, #T_35d7e_row1_col17, #T_35d7e_row1_col18, #T_35d7e_row1_col19, #T_35d7e_row1_col20, #T_35d7e_row1_col21, #T_35d7e_row1_col22, #T_35d7e_row1_col23, #T_35d7e_row1_col24, #T_35d7e_row1_col25, #T_35d7e_row1_col26, #T_35d7e_row1_col27, #T_35d7e_row1_col28, #T_35d7e_row1_col29, #T_35d7e_row1_col30, #T_35d7e_row1_col31, #T_35d7e_row1_col32, #T_35d7e_row1_col33, #T_35d7e_row1_col34, #T_35d7e_row1_col35, #T_35d7e_row1_col36, #T_35d7e_row1_col37, #T_35d7e_row2_col4, #T_35d7e_row2_col5, #T_35d7e_row2_col6, #T_35d7e_row2_col7, #T_35d7e_row2_col8, #T_35d7e_row2_col9, #T_35d7e_row2_col10, #T_35d7e_row2_col11, #T_35d7e_row2_col12, #T_35d7e_row2_col13, #T_35d7e_row2_col14, #T_35d7e_row2_col15, #T_35d7e_row2_col16, #T_35d7e_row2_col17, #T_35d7e_row2_col18, #T_35d7e_row2_col19, #T_35d7e_row2_col20, #T_35d7e_row2_col21, #T_35d7e_row2_col22, #T_35d7e_row2_col23, #T_35d7e_row2_col24, #T_35d7e_row2_col25, #T_35d7e_row2_col26, #T_35d7e_row2_col27, #T_35d7e_row2_col28, #T_35d7e_row2_col29, #T_35d7e_row2_col30, #T_35d7e_row3_col4, #T_35d7e_row3_col5, #T_35d7e_row3_col6, #T_35d7e_row3_col7, #T_35d7e_row3_col8, #T_35d7e_row3_col9, #T_35d7e_row3_col10, #T_35d7e_row3_col11, #T_35d7e_row3_col12, #T_35d7e_row3_col13, #T_35d7e_row3_col14, #T_35d7e_row3_col15, #T_35d7e_row3_col16, #T_35d7e_row3_col17, #T_35d7e_row3_col18, #T_35d7e_row3_col24, #T_35d7e_row3_col25, #T_35d7e_row3_col26, #T_35d7e_row3_col27, #T_35d7e_row3_col30, #T_35d7e_row3_col31, #T_35d7e_row3_col32, #T_35d7e_row3_col33, #T_35d7e_row3_col34, #T_35d7e_row3_col35, #T_35d7e_row3_col36, #T_35d7e_row3_col37, #T_35d7e_row4_col4, #T_35d7e_row4_col5, #T_35d7e_row4_col7, #T_35d7e_row4_col8, #T_35d7e_row4_col9, #T_35d7e_row4_col10, #T_35d7e_row4_col11, #T_35d7e_row4_col12, #T_35d7e_row4_col13, #T_35d7e_row4_col14, #T_35d7e_row4_col15, #T_35d7e_row4_col16, #T_35d7e_row4_col17, #T_35d7e_row4_col18, #T_35d7e_row4_col19, #T_35d7e_row4_col20, #T_35d7e_row4_col21, #T_35d7e_row4_col22, #T_35d7e_row4_col23, #T_35d7e_row4_col24, #T_35d7e_row4_col35, #T_35d7e_row4_col36, #T_35d7e_row4_col37, #T_35d7e_row5_col4, #T_35d7e_row5_col5, #T_35d7e_row5_col6, #T_35d7e_row5_col7, #T_35d7e_row5_col8, #T_35d7e_row5_col14, #T_35d7e_row5_col23, #T_35d7e_row5_col24, #T_35d7e_row5_col25, #T_35d7e_row5_col26, #T_35d7e_row5_col27, #T_35d7e_row5_col28, #T_35d7e_row5_col29, #T_35d7e_row5_col30, #T_35d7e_row5_col31, #T_35d7e_row5_col32, #T_35d7e_row5_col33, #T_35d7e_row5_col34, #T_35d7e_row5_col35, #T_35d7e_row5_col36, #T_35d7e_row5_col37, #T_35d7e_row6_col4, #T_35d7e_row6_col5, #T_35d7e_row6_col6, #T_35d7e_row6_col7, #T_35d7e_row6_col8, #T_35d7e_row6_col9, #T_35d7e_row6_col10, #T_35d7e_row6_col11, #T_35d7e_row6_col12, #T_35d7e_row6_col13, #T_35d7e_row6_col14, #T_35d7e_row6_col15, #T_35d7e_row6_col16, #T_35d7e_row6_col17, #T_35d7e_row6_col18, #T_35d7e_row6_col19, #T_35d7e_row6_col20, #T_35d7e_row6_col29, #T_35d7e_row6_col30, #T_35d7e_row6_col31, #T_35d7e_row6_col32, #T_35d7e_row6_col33, #T_35d7e_row6_col34, #T_35d7e_row6_col35, #T_35d7e_row6_col36, #T_35d7e_row6_col37, #T_35d7e_row7_col4, #T_35d7e_row7_col5, #T_35d7e_row7_col6, #T_35d7e_row7_col7, #T_35d7e_row7_col8, #T_35d7e_row7_col9, #T_35d7e_row7_col10, #T_35d7e_row7_col11, #T_35d7e_row7_col12, #T_35d7e_row7_col13, #T_35d7e ...

# %% [markdown]
# Напишем функцию **`year_top_6_leaders`**, которая выберет определенный период и платформы для построения графика, анализировать будем весь период, чтобы более детально можно посмотреть жизненный цикл платформы.

# %%
# Создадим функцию
def year_top_6_leaders(name, df):
    # Сделаем срез данных по названию платформы и году выпуска с 1980 г, чтобы полностью посмотреть динамику
    cut = df.loc[(df['platform'] == name) & (df['year_of_release'] >= 1980)]
    # Сгруппируем 
    #leaders = cut.groupby('year_of_release', sort=False)['total_sales_regions'].sum()
    leaders = cut.pivot_table(index='year_of_release', values='total_sales_regions', aggfunc='sum')\
                  .sort_values('year_of_release', ascending=False)
    return leaders

# %% [markdown]
# Построим на графике распределение по годам

# %%
# Создадим график
top_6_leaders = top_6_leaders.reset_index().rename_axis(None, axis=1)
plt.figure(figsize=(15,7)) # название графика
plt.grid(True) # сетка
plt.title('Динамика продаж основных лидеров с 1980 по 2016 гг')
plt.xlabel('Год выпуска') # подпись оси x
plt.ylabel('Объем продаж') # подпись оси y
 
# Создаем цикл 
for item in list(top_6_leaders['platform']): 
    sns.lineplot(data = year_top_6_leaders(item,games)['total_sales_regions'], label = item)
    plt.legend()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
# * Средний жизненный цикл платформ в рамках 8 лет;
# * На графике четко прослеживается рост-пик-спад каждой платформы;
# * Основными сменяющими лидерами были PS, после него PS2 (PlayStation 2) и Wii;
# * В категорию **прибыльной платформы**, по факторам длительности существования и спроса, можно отнести **платформы PlayStation**.
#
# <span class="girk">**"Первопроходцем"**</span> в игровой индустрии стала <font color='green'>**платформа DS**</font>, которая вышла на рынок в 1985 и ушла с рынка в 2013 году.\
# Основной подъем популярности платформы был в 2004 по 2008 гг. Предположительно, компания решила провести агрессивную маркетинговую кампанию по увеличению спроса на продукт.
#
# <span class="girk">**"Инноватором"**</span> стала <font color='green'>**платформа PS2 (PlayStation 2)**</font>, которая занимала лидирующие позиции с 2000 по 2004 гг. и послужила мощным толчком в индустрии ирг, после чего пришло на рынок много играков. После 2004 до 2011 наблюдается спад и пониженный спрос.
#
# C 2004 по 2005 гг на рынок вышли новые платформы, такие как PS3 (замена PS2), Х360 и Wii, с основным пиком в 5 лет, после чего последовал резкий спад.

# %% [markdown]
# #### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %% [markdown]
# **За актуальный период для дальнейшего анализа возьмем 3 года (с 2012 по 2015 гг. включительно)**

# %%
# Обновим датасет с новым периодом для дальнейшего анализа 

games_update = games.loc[(games['year_of_release'].isna()) | (games['year_of_release']>= 2013)\
                & (games['year_of_release']<=2016)]

# %%
games_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2237 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 2237 non-null   object
#  1   platform             2237 non-null   object
#  2   year_of_release      2237 non-null   Int64
#  3   genre                2237 non-null   object
#  4   na_sales             2237 non-null   float64
#  5   eu_sales             2237 non-null   float64
#  6   jp_sales             2237 non-null   float64
#  7   other_sales          2237 non-null   float64
#  8   critic_score         2237 non-null   Int64
#  9   user_score           2237 non-null   float64
#  10  rating               2237 non-null   object
#  11  total_sales_regions  2237 non-null   float64
# dtypes: Int64(2), float64(6), object(4)
# memory usage: 231.6+ KB

# %% [markdown]
# Построим коробчатую диаграмму размаха ("ящик с усами") и сохраним данные в переменной `games_boxplot`, удалим выбросы по объему продаж от 2 млн. копий

# %%
games_boxplot = games_update.loc[(games_update['total_sales_regions'] <= 2)] 

plt.show()

sns.set(rc={'figure.figsize':(15,8)})
ax = sns.boxplot(x='platform', y='total_sales_regions', data=games_boxplot)
plt.title("Диаграмма размаха по глобальным продажам игр в разбивке по платформам", fontsize=15)
plt.xlabel('Название платформы') # подпись оси x
plt.ylabel('Объем продаж(млн.шт)') # подпись оси y
plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
# * **Максимальный годовой объем продаж** в диапозоне 1 -1.4 млн.копий показали такие платформы, как Х360, PS4, ХOne и WiiU;
# * **Медианные значения** у всех разные и находятся в диапозоне от 50 до 240 тыс. копий;
# * **Минимальный годовой объем продаж** по нашей выборке примерно 20  тыс.копии;
# * **Выбросы** - это значения, которые очень далеки от общей выборки. В данном случаи, все что выше 2 млн.копий мы удалили.

# %% [markdown]
# #### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы. Соотнесите выводы с продажами игр на других платформах.

# %% [markdown]
# ##### Диаграмма рассеяния (отзывы пользователей и продажи)

# %% [markdown]
# Построим диаграмму рассеяния, убрав из данных заглушки и выбросы более 10 млн. копий

# %%
# Уберем заглушки (-999) и выбросы (total_sales_regions < 10)
games_update[games_update['user_score'] > -999].query('total_sales_regions < 10')\
                     .plot(kind='scatter', y='user_score'\
                    , x='total_sales_regions', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общий объем продаж — отзывы пользователей')
plt.xlabel('Объем продаж(млн.шт)') # подпись оси x
plt.ylabel('Оценка пользователей') # подпись оси y
plt.show()

# Рассчитаем корреляцию
games_update[['user_score','total_sales_regions']].corr()
# Out:
#                      user_score  total_sales_regions
# user_score              1.00000              0.16287
# total_sales_regions     0.16287              1.00000

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> На диаграмме видно, что прямой корреляции между оценкой пользователей и продажами нет. Согласно Шкале Чеддока, коэффициент корреляции **0.16** определим, как **"слабая"** связь.

# %% [markdown]
# ##### Диаграмма рассеяния (отзывы критиков и продажи)

# %% [markdown]
# Построим диаграмму рассеяния, убрав из данных заглушки и выбросы более 10 млн. копий

# %%
# Уберем заглушки (-999) и выбросы (total_sales_regions < 10)
games_update[games_update['critic_score'] > -999].query('total_sales_regions < 10').plot(kind='scatter', y='critic_score'\
                    , x='total_sales_regions', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общий объем продаж — оценка критиков')
plt.xlabel('Объем продаж(млн.шт)') # подпись оси x
plt.ylabel('Оценка критиков') # подпись оси y
plt.show()

# Рассчитаем корреляцию
games_update[['total_sales_regions','critic_score']].corr()
# Out:
#                      total_sales_regions  critic_score
# total_sales_regions             1.000000      0.172021
# critic_score                    0.172021      1.000000

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> На диаграмме видно, что прямой корреляции между оценкой критиков и продажами нет. Согласно Шкале Чеддока, коэффициент корреляции **0.17** определим, как **"слабая"** связь.
#
# Есть предположение, что данные оценки, в тот период времени, не были широко офишированны в СМИ и в общем доступе не находились. Возможно данные собирались только для личного пользования компаниями и не влияли на выбор потребителей.

# %% [markdown]
# **Рассмотрим влияние на продажи игр для платформы PS4 отзывов пользователей и критиков.**

# %%
games_new = games_update[(games_update['user_score'] > -999)|
                             (games_update['critic_score'] > -999)].query('total_sales_regions < 10')

# %% [markdown]
# Рассмотрим влияние на продажи игр для платформы PS4 отзывов пользователей и критиков.

# %%
games_update_critic = games_update[(games_update['critic_score'] > -999)].query('total_sales_regions < 10')

games_update_user = games_update[(games_update['user_score'] > -999)].query('total_sales_regions < 10')

fig = plt.figure()

ax_1 = fig.add_subplot(1, 2, 1)
ax_2 = fig.add_subplot(1, 2, 2)

sns.scatterplot(data=games_update_critic.query('platform == "PS4"'),
                x='critic_score', y='total_sales_regions', 
                color='red', alpha=0.5,  
                ax=ax_1)

sns.scatterplot(data=games_update_user.query('platform == "PS4"'),
                x='user_score', y='total_sales_regions', 
                color='orange', alpha=0.5,
                ax=ax_2)

ax_1.set_title('Диаграмма рассеяния PS4: оценка критика - продажи')
ax_2.set_title('Диаграмма рассеяния PS4: оценка пользователей - продажи')


fig.set_figwidth(20)
fig.set_figheight(7)

plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
#
# По данным диаграмам можно сделать вывод, что большей популярностью пользуются игры:
#
# * имеющие пользовательский рейтинг более 6 баллов;
# * имеющие оценку критиков более 60 баллов;
# * игр с пользовательской оценкой в 10 баллов не обнаружено

# %%
corr_ps4_user = games_update_user.query('platform == "PS4"')
print('Корреляция между оценками пользователей и продажами:', \
      corr_ps4_user['user_score'].corr(corr_ps4_user['total_sales_regions']))
# Out:
# Корреляция между оценками пользователей и продажами: -0.06935386232766949

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
# Корреляция между оценками пользователей и продажами PS4 не выявлена.

# %% [markdown]
# Рассмотрим влияние на продажи игр для платформы XOne отзывов пользователей и критиков.

# %%
#построим диаграммы рассеяния для Xone
fig = plt.figure()

ax_1 = fig.add_subplot(1, 2, 1)
ax_2 = fig.add_subplot(1, 2, 2)

sns.scatterplot(data=games_update_critic.query('platform == "XOne"'),
                x='critic_score', y='total_sales_regions', 
                color='blue', alpha=0.5,  
                ax=ax_1)

sns.scatterplot(data=games_update_user.query('platform == "XOne"'),
                x='user_score', y='total_sales_regions', 
                color='green', alpha=0.5,
                ax=ax_2)

ax_1.set_title('Диаграмма рассеяния XOne: оценка критика - продажи')
ax_2.set_title('Диаграмма рассеяния XOne: оценка пользователей - продажи')


fig.set_figwidth(20)
fig.set_figheight(7)

plt.show()

# %%
corr_XOne_user = games_update_user.query('platform == "XOne"')
print('Корреляция между оценками пользователей и продажами:', \
      corr_XOne_user['user_score'].corr(corr_XOne_user['total_sales_regions']))
# Out:
# Корреляция между оценками пользователей и продажами: -0.06892505328279414

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
# У игр платформы XOne корреляция продаж от оценок идентична с платформой PS4, слабая зависимость от оценки критиков (коэффициент корреляции) и отсуствующая зависимость от оценки пользователей (коэффициент корреляции).

# %% [markdown]
# #### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Сформируем таблицу с количесвом игр и общие продажи в разрезе всех жанров. Отфильтруем столбец total_sales_regions по убыванию для наглядности.

# %%
genre_total = games_update.groupby('genre').agg({'name': 'count', 'total_sales_regions': 'sum'})\
                                    .sort_values('total_sales_regions', ascending=False)\
                                    .reset_index()

genre_total.style.bar(subset=['name', 'total_sales_regions'], color='#5fd6d6')
# Out:
# <style type="text/css">
# #T_d9b80_row0_col1, #T_d9b80_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 100.0%, transparent 100.0%);
# }
# #T_d9b80_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 24.3%, transparent 24.3%);
# }
# #T_d9b80_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 72.2%, transparent 72.2%);
# }
# #T_d9b80_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 27.8%, transparent 27.8%);
# }
# #T_d9b80_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 46.7%, transparent 46.7%);
# }
# #T_d9b80_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 38.0%, transparent 38.0%);
# }
# #T_d9b80_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 45.2%, transparent 45.2%);
# }
# #T_d9b80_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 20.3%, transparent 20.3%);
# }
# #T_d9b80_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 19.6%, transparent 19.6%);
# }
# #T_d9b80_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 9.6%, transparent 9.6%);
# }
# #T_d9b80_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 13.2%, transparent 13.2%);
# }
# #T_d9b80_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 11.1%, transparent 11.1%);
# }
# #T_d9b80_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 12.4%, transparent 12.4%);
# }
# #T_d9b80_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 10.4%, transparent 10.4%);
# }
# #T_d9b80_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 10.9%, transparent 10.9%);
# }
# #T_d9b80_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 31.9%, transparent 31.9%);
# }
# #T_d9b80_row8_col2, #T_d9b80_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 7.3%, transparent 7.3%);
# }
# #T_d9b80_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 8.1%, transparent 8.1%);
# }
# #T_d9b80_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 6.7%, transparent 6.7%);
# }
# #T_d9b80_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 3.1%, transparent 3.1%);
# }
# #T_d9b80_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 2.2%, transparent 2.2%);
# }
# #T_d9b80_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fd6d6 1.0%, transparent 1.0%);
# }
# </style>
# <table id="T_d9b80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b80_level0_col0" class="col_heading level0 col0" >genre</th>
#       <th id="T_d9b80_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_d9b80_level0_col2" class="col_heading level0 col2" >total_sales_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b80_row0_col0" class="data row0 col0" >Action</td>
#       <td id="T_d9b80_row0_col1" class="data row0 col1" >769</td>
#       <td id="T_d9b80_row0_col2" class="data row0 col2" >322.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9b80_row1_col0" class="data row1 col0" >Shooter</td>
#       <td id="T_d9b80_row1_col1" class="data row1 col1" >187</td>
#       <td id="T_d9b80_row1_col2" class="data row1 col2" >232.980000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9b80_row2_col0" class="data row2 col0" >Sports</td>
#       <td id="T_d9b80_row2_col1" class="data row2 col1" >214</td>
#       <td id="T_d9b80_row2_col2" class="data row2 col2" >150.650000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9b80_row3_col0" class="data row3 col0" >Role-Playing</td>
#       <td id="T_d9b80_row3_col1" class="data row3 col1" >292</td>
#       <td id="T_d9b80_row3_col2" class="data row3 col2" >145.890000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9b80_row4_col0" class="data row4 col0" >Misc</td>
#       <td id="T_d9b80_row4_col1" class="data row4 col1" >156</td>
#       <td id="T_d9b80_row4_col2" class="data row4 col2" >63.060000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9b80_row5_col0" class="data row5 col0" >Platform</td>
#       <td id="T_d9b80_row5_col1" class="data row5 col1" >74</td>
#       <td id="T_d9b80_row5_col2" class="data row5 col2" >42.630000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9b80_row6_col0" class="data row6 col0" >Racing</td>
#       <td id="T_d9b80_row6_col1" class="data row6 col1" >85</td>
#       <td id="T_d9b80_row6_col2" class="data row6 col2" >39.890000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9b80_row7_col0" class="data row7 col0" >Fighting</td>
#       <td id="T_d9b80_row7_col1" class="data row7 col1" >80</td>
#       <td id="T_d9b80_row7_col2" class="data row7 col2" >35.310000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9b80_row8_col0" class="data row8 col0" >Adventure</td>
#       <td id="T_d9b80_row8_col1" class="data row8 col1" >245</td>
#       <td id="T_d9b80_row8_col2" class="data row8 col2" >23.640000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9b80_row9_col0" class="data row9 col0" >Simulation</td>
#       <td id="T_d9b80_row9_col1" class="data row9 col1" >62</td>
#       <td id="T_d9b80_row9_col2" class="data row9 col2" >21.760000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d9b80_row10_col0" class="data row10 col0" >Strategy</td>
#       <td id="T_d9b80_row10_col1" class="data row10 col1" >56</td>
#       <td id="T_d9b80_row10_col2" class="data row10 col2" >10.080000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b80_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d9b80_row11_col0" class="data row11 col0" >Puzzle</td>
#       <td id="T_d9b80_row11_col1" class="data row11 col1" >17</td>
#       <td id="T_d9b80_row11_col2" class="data row11 col2" >3.170000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Построим график распределения медианных продаж, количества игр в разрезе жанров**

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=games_update, x='genre', y='total_sales_regions')
plt.ylim([0, 2])
plt.xlabel('Жанры', fontsize=15)
plt.ylabel('Количество проданных игр, млн копий', fontsize=15)
plt.title('Распределение игр по жанрам', fontsize=20);

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>
# * Медианные продажи выше всего в жанре shooter, на втором месте sports, на третьем platform
# * Согласно вышеуказанной таблице, наиболее **прибыльными и популятными** жанрами стали Action, Shooter, Role-Playing и Sports.
# * Жанр Adventure можно отнести с **низкоприбыльным**, тк при большом количестве игр, продажи крайне малы.
# * Жанр Shooter можно выделить среди прибыльных, тк при меньшем количестве игр, они заняли второе место по объему продаж.

# %% [markdown]
# ### Составьте портрет пользователя каждого региона
#
# * Определите для пользователя каждого региона (NA, EU, JP):
#  - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#  - Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
#регионы для анализа
regions = ['na_sales', 'eu_sales', 'jp_sales']

# %%
#функция вывода гистограмм по регионам в разрезе параметра plot_index

def region_plot (plot_index):
    '''функция построения гистограмм распределения продаж в разрезе ТОП-5 
       заданного параметра по каждому региону исследования'''
    
    fig, axs = plt.subplots(1, 3, figsize=(18,6))
    
    for i in range(len(regions)):
        
        df_i = games_update.groupby(plot_index)[regions[i]].sum().reset_index().sort_values(by=regions[i], ascending=False).head(5)
        #print(df_i)
        axs[i].bar(df_i[plot_index], df_i[regions[i]], color='maroon')
        axs[i].set_title(regions[i])
    
    plt.show()

# %%
#функция вывода круговой диаграммы по регионам в разрезе параметра plot_index

def region_plot_pie (plot_index):
    '''функция построения гистограмм распределения продаж в разрезе ТОП-5 
       заданного параметра по каждому региону исследования'''
    
    fig, axs = plt.subplots(1, 3, figsize=(18,6))
    
    for i in range(len(regions)):
        
        df_i = (games_update
                .groupby(plot_index)[regions[i]]
                .agg('sum')
                .reset_index()
                .sort_values(by=regions[i], ascending=False)
                .head(5)
                )
        sale_other = (games_update[regions[i]].sum() - df_i[regions[i]].sum()).round(2)
        df_i.loc[len(df_i.index)] = ['Others', sale_other]
        #print(df_i)
        axs[i].pie(df_i[regions[i]], labels=df_i[plot_index], autopct='%1.0f%%', pctdistance=0.7)
        axs[i].set_title(regions[i])
    
    plt.show()

# %% [markdown]
# ####  Сводная по регионам (NA, EU, JP)

# %% [markdown]
# Создадим таблицу в разрезе платформ и продаж каждого региона с 2013 по 2016 гг.

# %%
regions_platforms = games_update.pivot_table(index='platform', values=['na_sales', 'eu_sales', 'jp_sales'],\
               aggfunc={'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum' }).reset_index()

regions_platforms.style.bar(subset=['na_sales', 'eu_sales', 'jp_sales'], color='#c5e89f')
# Out:
# <style type="text/css">
# #T_31ca3_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 21.9%, transparent 21.9%);
# }
# #T_31ca3_row0_col2, #T_31ca3_row4_col1, #T_31ca3_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 100.0%, transparent 100.0%);
# }
# #T_31ca3_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 35.1%, transparent 35.1%);
# }
# #T_31ca3_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.6%, transparent 0.6%);
# }
# #T_31ca3_row1_col2, #T_31ca3_row2_col2, #T_31ca3_row5_col3 {
#   width: 10em;
# }
# #T_31ca3_row1_col3, #T_31ca3_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.5%, transparent 0.5%);
# }
# #T_31ca3_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 18.3%, transparent 18.3%);
# }
# #T_31ca3_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 10.3%, transparent 10.3%);
# }
# #T_31ca3_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 48.1%, transparent 48.1%);
# }
# #T_31ca3_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 34.4%, transparent 34.4%);
# }
# #T_31ca3_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 58.4%, transparent 58.4%);
# }
# #T_31ca3_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 23.5%, transparent 23.5%);
# }
# #T_31ca3_row5_col1, #T_31ca3_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.1%, transparent 0.1%);
# }
# #T_31ca3_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 5.2%, transparent 5.2%);
# }
# #T_31ca3_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 4.3%, transparent 4.3%);
# }
# #T_31ca3_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 27.4%, transparent 27.4%);
# }
# #T_31ca3_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 4.6%, transparent 4.6%);
# }
# #T_31ca3_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 4.2%, transparent 4.2%);
# }
# #T_31ca3_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 6.0%, transparent 6.0%);
# }
# #T_31ca3_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 14.1%, transparent 14.1%);
# }
# #T_31ca3_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 16.0%, transparent 16.0%);
# }
# #T_31ca3_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 26.9%, transparent 26.9%);
# }
# #T_31ca3_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 30.1%, transparent 30.1%);
# }
# #T_31ca3_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.8%, transparent 0.8%);
# }
# #T_31ca3_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 75.1%, transparent 75.1%);
# }
# #T_31ca3_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 36.6%, transparent 36.6%);
# }
# #T_31ca3_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 85.6%, transparent 85.6%);
# }
# </style>
# <table id="T_31ca3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31ca3_level0_col0" class="col_heading level0 col0" >platform</th>
#       <th id="T_31ca3_level0_col1" class="col_heading level0 col1" >eu_sales</th>
#       <th id="T_31ca3_level0_col2" class="col_heading level0 col2" >jp_sales</th>
#       <th id="T_31ca3_level0_col3" class="col_heading level0 col3" >na_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31ca3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31ca3_row0_col0" class="data row0 col0" >3DS</td>
#       <td id="T_31ca3_row0_col1" class="data row0 col1" >30.960000</td>
#       <td id="T_31ca3_row0_col2" class="data row0 col2" >67.810000</td>
#       <td id="T_31ca3_row0_col3" class="data row0 col3" >38.200000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31ca3_row1_col0" class="data row1 col0" >DS</td>
#       <td id="T_31ca3_row1_col1" class="data row1 col1" >0.850000</td>
#       <td id="T_31ca3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_31ca3_row1_col3" class="data row1 col3" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31ca3_row2_col0" class="data row2 col0" >PC</td>
#       <td id="T_31ca3_row2_col1" class="data row2 col1" >25.840000</td>
#       <td id="T_31ca3_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_31ca3_row2_col3" class="data row2 col3" >11.190000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31ca3_row3_col0" class="data row3 col0" >PS3</td>
#       <td id="T_31ca3_row3_col1" class="data row3 col1" >67.810000</td>
#       <td id="T_31ca3_row3_col2" class="data row3 col2" >23.350000</td>
#       <td id="T_31ca3_row3_col3" class="data row3 col3" >63.500000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_31ca3_row4_col0" class="data row4 col0" >PS4</td>
#       <td id="T_31ca3_row4_col1" class="data row4 col1" >141.090000</td>
#       <td id="T_31ca3_row4_col2" class="data row4 col2" >15.960000</td>
#       <td id="T_31ca3_row4_col3" class="data row4 col3" >108.740000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_31ca3_row5_col0" class="data row5 col0" >PSP</td>
#       <td id="T_31ca3_row5_col1" class="data row5 col1" >0.170000</td>
#       <td id="T_31ca3_row5_col2" class="data row5 col2" >3.530000</td>
#       <td id="T_31ca3_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_31ca3_row6_col0" class="data row6 col0" >PSV</td>
#       <td id="T_31ca3_row6_col1" class="data row6 col1" >6.100000</td>
#       <td id="T_31ca3_row6_col2" class="data row6 col2" >18.590000</td>
#       <td id="T_31ca3_row6_col3" class="data row6 col3" >5.040000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_31ca3_row7_col0" class="data row7 col0" >Wii</td>
#       <td id="T_31ca3_row7_col1" class="data row7 col1" >5.930000</td>
#       <td id="T_31ca3_row7_col2" class="data row7 col2" >0.050000</td>
#       <td id="T_31ca3_row7_col3" class="data row7 col3" >6.560000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_31ca3_row8_col0" class="data row8 col0" >WiiU</td>
#       <td id="T_31ca3_row8_col1" class="data row8 col1" >19.850000</td>
#       <td id="T_31ca3_row8_col2" class="data row8 col2" >10.880000</td>
#       <td id="T_31ca3_row8_col3" class="data row8 col3" >29.210000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_31ca3_row9_col0" class="data row9 col0" >X360</td>
#       <td id="T_31ca3_row9_col1" class="data row9 col1" >42.520000</td>
#       <td id="T_31ca3_row9_col2" class="data row9 col2" >0.510000</td>
#       <td id="T_31ca3_row9_col3" class="data row9 col3" >81.660000</td>
#     </tr>
#     <tr>
#       <th id="T_31ca3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_31ca3_row10_col0" class="data row10 col0" >XOne</td>
#       <td id="T_31ca3_row10_col1" class="data row10 col1" >51.590000</td>
#       <td id="T_31ca3_row10_col2" class="data row10 col2" >0.340000</td>
#       <td id="T_31ca3_row10_col3" class="data row10 col3" >93.120000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Найдем самые популярные платформы (топ-5) и укажем долю продаж.

# %%
# Сгруппируем платформы и продажи по регионам в период с 2013 по 2016 гг. и создадим круговую диаграмму
region_plot_pie('platform')

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> Согласно вышеуказанным данным, можно сделать следующее заключение:
# * `Северная Америка`: в топ 5 по объему продаж вошли такие платформы, как **PS4(25%), XOne(21%) Х360(19%), PS3(15%) и 3DS(9%)**
#
# * `Европа`: в топ 5 по объему продаж вошли такие платформы, как **PS4(36%), PS3(17%), Х360(12%), XOne(13%) и PC(7%)**
#
# * `Япония`: в топ 5 по объему продаж вошли такие платформы, как **3DS(48%), PS3(17%), PSV(13%),  PS4(11%) и WiiU(8%)**
#
# <span class="girk">Стоит отметить, что предпочтения пользователей в Северной Америке и Европе практически совпали по популярности одних и тех же платфор, что нельзя сказать про Японию, которая имеет основного "любимчика" 3DS и отдает ему 48% доли рынка.</span>

# %% [markdown]
# **Найдем самые популярные жанры (топ-5) и укажем долю продаж.**

# %% [markdown]
# Создадим таблицу в разрезе платформ и продаж каждого региона с 2013 по 2016 гг.

# %%
regions_genre = games_update.pivot_table(index='genre', values=['na_sales', 'eu_sales', 'jp_sales'],\
               aggfunc={'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum' }).reset_index()

regions_genre.style.bar(subset=['na_sales', 'eu_sales', 'jp_sales'], color='#c5e89f')
# Out:
# <style type="text/css">
# #T_69296_row0_col1, #T_69296_row0_col3, #T_69296_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 100.0%, transparent 100.0%);
# }
# #T_69296_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 79.3%, transparent 79.3%);
# }
# #T_69296_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 7.0%, transparent 7.0%);
# }
# #T_69296_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 11.4%, transparent 11.4%);
# }
# #T_69296_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 5.7%, transparent 5.7%);
# }
# #T_69296_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 7.2%, transparent 7.2%);
# }
# #T_69296_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 15.0%, transparent 15.0%);
# }
# #T_69296_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 12.3%, transparent 12.3%);
# }
# #T_69296_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 16.9%, transparent 16.9%);
# }
# #T_69296_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 18.5%, transparent 18.5%);
# }
# #T_69296_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 21.8%, transparent 21.8%);
# }
# #T_69296_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 13.1%, transparent 13.1%);
# }
# #T_69296_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 9.4%, transparent 9.4%);
# }
# #T_69296_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 14.4%, transparent 14.4%);
# }
# #T_69296_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.8%, transparent 0.8%);
# }
# #T_69296_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 2.3%, transparent 2.3%);
# }
# #T_69296_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 0.7%, transparent 0.7%);
# }
# #T_69296_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 17.0%, transparent 17.0%);
# }
# #T_69296_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 4.5%, transparent 4.5%);
# }
# #T_69296_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 10.3%, transparent 10.3%);
# }
# #T_69296_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 31.2%, transparent 31.2%);
# }
# #T_69296_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 36.8%, transparent 36.8%);
# }
# #T_69296_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 74.1%, transparent 74.1%);
# }
# #T_69296_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 13.0%, transparent 13.0%);
# }
# #T_69296_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 87.0%, transparent 87.0%);
# }
# #T_69296_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 9.2%, transparent 9.2%);
# }
# #T_69296_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 8.9%, transparent 8.9%);
# }
# #T_69296_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 3.9%, transparent 3.9%);
# }
# #T_69296_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 51.0%, transparent 51.0%);
# }
# #T_69296_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 10.6%, transparent 10.6%);
# }
# #T_69296_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 51.7%, transparent 51.7%);
# }
# #T_69296_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 3.6%, transparent 3.6%);
# }
# #T_69296_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 3.5%, transparent 3.5%);
# }
# #T_69296_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 2.6%, transparent 2.6%);
# }
# </style>
# <table id="T_69296">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69296_level0_col0" class="col_heading level0 col0" >genre</th>
#       <th id="T_69296_level0_col1" class="col_heading level0 col1" >eu_sales</th>
#       <th id="T_69296_level0_col2" class="col_heading level0 col2" >jp_sales</th>
#       <th id="T_69296_level0_col3" class="col_heading level0 col3" >na_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69296_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69296_row0_col0" class="data row0 col0" >Action</td>
#       <td id="T_69296_row0_col1" class="data row0 col1" >118.610000</td>
#       <td id="T_69296_row0_col2" class="data row0 col2" >40.490000</td>
#       <td id="T_69296_row0_col3" class="data row0 col3" >126.130000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69296_row1_col0" class="data row1 col0" >Adventure</td>
#       <td id="T_69296_row1_col1" class="data row1 col1" >8.250000</td>
#       <td id="T_69296_row1_col2" class="data row1 col2" >5.820000</td>
#       <td id="T_69296_row1_col3" class="data row1 col3" >7.140000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69296_row2_col0" class="data row2 col0" >Fighting</td>
#       <td id="T_69296_row2_col1" class="data row2 col1" >8.550000</td>
#       <td id="T_69296_row2_col2" class="data row2 col2" >7.650000</td>
#       <td id="T_69296_row2_col3" class="data row2 col3" >15.550000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69296_row3_col0" class="data row3 col0" >Misc</td>
#       <td id="T_69296_row3_col1" class="data row3 col1" >20.040000</td>
#       <td id="T_69296_row3_col2" class="data row3 col2" >9.440000</td>
#       <td id="T_69296_row3_col3" class="data row3 col3" >27.490000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69296_row4_col0" class="data row4 col0" >Platform</td>
#       <td id="T_69296_row4_col1" class="data row4 col1" >15.580000</td>
#       <td id="T_69296_row4_col2" class="data row4 col2" >4.790000</td>
#       <td id="T_69296_row4_col3" class="data row4 col3" >18.140000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69296_row5_col0" class="data row5 col0" >Puzzle</td>
#       <td id="T_69296_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_69296_row5_col2" class="data row5 col2" >1.180000</td>
#       <td id="T_69296_row5_col3" class="data row5 col3" >0.830000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69296_row6_col0" class="data row6 col0" >Racing</td>
#       <td id="T_69296_row6_col1" class="data row6 col1" >20.190000</td>
#       <td id="T_69296_row6_col2" class="data row6 col2" >2.300000</td>
#       <td id="T_69296_row6_col3" class="data row6 col3" >12.960000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69296_row7_col0" class="data row7 col0" >Role-Playing</td>
#       <td id="T_69296_row7_col1" class="data row7 col1" >36.970000</td>
#       <td id="T_69296_row7_col2" class="data row7 col2" >51.040000</td>
#       <td id="T_69296_row7_col3" class="data row7 col3" >46.400000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69296_row8_col0" class="data row8 col0" >Shooter</td>
#       <td id="T_69296_row8_col1" class="data row8 col1" >87.860000</td>
#       <td id="T_69296_row8_col2" class="data row8 col2" >6.610000</td>
#       <td id="T_69296_row8_col3" class="data row8 col3" >109.740000</td>
#     </tr>
#     <tr>
#       <th id="T_69296_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69296_row9_col0" class="data row9 col0" >Simulation</td>
#       <td id="T_69296_row9_col1" class="data row9 col1" >10.920000</td>
#       <td id="T_69296_row9_col2" class="data row9 col2" >4.520000</td>
#       <td id="T_69296_row9_col3" class="data row9 col

# %%
# Сгруппируем жанры и продажи по регионам в период с 2013 по 2016 гг. и создадим круговую диаграмму
region_plot_pie('genre')

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> Согласно вышеуказанным данным, можно сделать следующее заключение:
# * `Северная Америка`: в топ 5 по объему продаж вошли такие жанры, как **Action(29%), Shooler(25%), Sports(15%), Role-Playing(11%) и Misc(6%)**
#
# * `Европа`: в топ 5 по объему продаж вошли такие жанры, как **Action(30%), Shooler(22%), Sports(15%), Role-Playing(9%) и Misc(6%)**
#
# * `Япония`: в топ 5 по объему продаж вошли такие платформы, как **Role-Playing(36%), Action(29%), Misc(7%),  Fighting(5%) и Shooler(5%)**
#
# <span class="girk">Стоит отметить, что предпочтения пользователей в Северной Америке и Европе практически совпали по популярности одних и тех же жанров, что нельзя сказать про Японию, которая отдала 65% доли объемов продаж на два жанра Role-Playing и Action . </span>

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# Расшифровка рейтингов:
#
# * «E» («Everyone») — «Для всех» от 6 лет
# * «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# * «T» («Teen») — «Подросткам» от 13 лет
# * «M» («Mature») — «Для взрослых» от 17 лет

# %%
# Исключим из анализа данные unknown
#games_update_rating = games_update.query('rating != "unknown"')

# Сгруппируем данные методом pivot_table по рейтингу странам 
regions_rating = games_update.pivot_table(index='rating', values=['na_sales', 'eu_sales', 'jp_sales'],\
               aggfunc={'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum' }).reset_index()

# Отформатируем ячейки для наглядности
regions_rating.style.bar(subset=['na_sales', 'eu_sales', 'jp_sales'], color='#c5e89f')
# Out:
# <style type="text/css">
# #T_6c337_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 57.2%, transparent 57.2%);
# }
# #T_6c337_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 17.8%, transparent 17.8%);
# }
# #T_6c337_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 47.8%, transparent 47.8%);
# }
# #T_6c337_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 29.3%, transparent 29.3%);
# }
# #T_6c337_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 6.9%, transparent 6.9%);
# }
# #T_6c337_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 32.8%, transparent 32.8%);
# }
# #T_6c337_row2_col1, #T_6c337_row2_col3, #T_6c337_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 100.0%, transparent 100.0%);
# }
# #T_6c337_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 16.5%, transparent 16.5%);
# }
# #T_6c337_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 28.8%, transparent 28.8%);
# }
# #T_6c337_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 24.1%, transparent 24.1%);
# }
# #T_6c337_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 30.1%, transparent 30.1%);
# }
# #T_6c337_row4_col1, #T_6c337_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #c5e89f 54.1%, transparent 54.1%);
# }
# </style>
# <table id="T_6c337">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c337_level0_col0" class="col_heading level0 col0" >rating</th>
#       <th id="T_6c337_level0_col1" class="col_heading level0 col1" >eu_sales</th>
#       <th id="T_6c337_level0_col2" class="col_heading level0 col2" >jp_sales</th>
#       <th id="T_6c337_level0_col3" class="col_heading level0 col3" >na_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c337_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c337_row0_col0" class="data row0 col0" >E</td>
#       <td id="T_6c337_row0_col1" class="data row0 col1" >83.360000</td>
#       <td id="T_6c337_row0_col2" class="data row0 col2" >15.140000</td>
#       <td id="T_6c337_row0_col3" class="data row0 col3" >79.050000</td>
#     </tr>
#     <tr>
#       <th id="T_6c337_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c337_row1_col0" class="data row1 col0" >E10+</td>
#       <td id="T_6c337_row1_col1" class="data row1 col1" >42.690000</td>
#       <td id="T_6c337_row1_col2" class="data row1 col2" >5.890000</td>
#       <td id="T_6c337_row1_col3" class="data row1 col3" >54.240000</td>
#     </tr>
#     <tr>
#       <th id="T_6c337_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c337_row2_col0" class="data row2 col0" >M</td>
#       <td id="T_6c337_row2_col1" class="data row2 col1" >145.800000</td>
#       <td id="T_6c337_row2_col2" class="data row2 col2" >14.110000</td>
#       <td id="T_6c337_row2_col3" class="data row2 col3" >165.290000</td>
#     </tr>
#     <tr>
#       <th id="T_6c337_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c337_row3_col0" class="data row3 col0" >T</td>
#       <td id="T_6c337_row3_col1" class="data row3 col1" >41.950000</td>
#       <td id="T_6c337_row3_col2" class="data row3 col2" >20.590000</td>
#       <td id="T_6c337_row3_col3" class="data row3 col3" >49.790000</td>
#     </tr>
#     <tr>
#       <th id="T_6c337_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c337_row4_col0" class="data row4 col0" >unknown</td>
#       <td id="T_6c337_row4_col1" class="data row4 col1" >78.910000</td>
#       <td id="T_6c337_row4_col2" class="data row4 col2" >85.290000</td>
#       <td id="T_6c337_row4_col3" class="data row4 col3" >89.420000</td>
#     </tr>
#   </tbody>
# </table>

# %%
 # круговая диаграмма для каждого региона
region_plot_pie('rating')

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> Согласно вышеуказанным данным, можно сделать следующее заключение:
# * `Северная Америка`: основное предпочтение отдано рейтингу **«M» («Mature») — «Для взрослых» и «E» («Everyone») — «Для всех»**
#
# * `Европа`: основное предпочтение отдано рейтингу **«M» («Mature») — «Для взрослых» и «E» («Everyone») — «Для всех»**
#
# * `Япония`: основное предпочтение отдано рейтингу **«E» («Everyone») — «Для всех» и «T» («Teen») — «Подросткам»**
#
# <span class="girk">Стоит отметить, что рейтинги в Северной Америке и Европе совпали, а в Японии, также кроме рейтинга "для всех", сильно выделился рейтинг "для подростков", что говорит, о высокой заинтересованности среди подростков от 13 лет. </span>

# %% [markdown]
# <p></p>
# <div style="border:solid green 2px; padding: 20px">
#        ОБЩИЙ ВЫВОД ПО ПОРТРЕТУ ПОТРЕБИТЕЛЯ ИГР ПО КАЖДОМУ РЕГИОНУ
#
#
# `Северная Америка`:
#
# * Самые популярные игровые платформы это: PS4, XOne, Х360, PS3, 3DS.
# * Топ 5 жанров в северной америке : action, shooler, sports, role-playing и misc
# * По рейтингам видно, что больше всего продаж у игр с рейтингом «Для взрослых» от 17 лет, на втором месте игры с рейтингом «Для всех»
#
# `Европа`:
# * Самые популярные игровые платформы это: PS4, PS3, Х360, XOne и PC
# * Топ 5 жанров в Европе : action, shooler, sports, role-playing и misc
# * По рейтингам видно, что больше всего продаж у игр с рейтингом «Для взрослых» от 17 лет, на втором месте игры с рейтингом «Для всех»
#
# `Япония`:
# * Самые популярные игровые платформы в Японии это: 3DS, PS3, PSV,PS4 и WiiU
# * Топ 5 жанров в Японии : role-playing, action, misc,  Fighting и shooler
# * По рейтингам видно, что больше всего продаж у игр с рейтингом "для всех", на втором месте игры с рейтингом «Подросткам» от 13 лет.
# * Большую долю рынка, занимают игры без рейтинга ESBR, особенно в Японии. Это говорит о том, что игры, которые производятся не в Северной Америке и Канаде, особого значения не придают этому рейтингу и соответвенно не подают документы на присвоение рейтинга данной организацией. Тем более, что и и в Европе и в Японии имеются свои рейтинги: - Pan European Game Information (PEGI) — европейская рейтинговая система компьютерных игр - Computer Entertainment Rating Organization (CERO) — японская некоммерческая организация, занимающаяся присуждением рейтингов компьютерным играм и программному обеспечению для их последующей продажи на территории Японии.
#
#  <span class="mark">Данные для прогноза лучше брать в ретроспективе за 3 года, чтобы был достаточный массив данных для выборки и данные не были устаревшими, так как индустрия игр довольна динамичная.</span>
#
#
#
# </div>

# %% [markdown]
# ### Проверьте гипотезы
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# * Задайте самостоятельно пороговое значение alpha.

# %% [markdown]
# Для проверки двух гипотез выберем метод `scipy.stats.ttest_ind`( гипотеза о равенстве средних двух совокупностей)
#
# Три аспекта, которые должны быть соблюдены:
# * генеральная совокупность не должна зависеть друг от друга;
# * выборочная средняя должна быть нормально распределена;
# * дисперсии рассматриваемых генеральных совокупностей должны быть равны

# %% [markdown]
# #### Проверка гипотезы №1:  "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"

# %% [markdown]
# <span class="girk">Формулировка гипотез:</span>
#
# * `Нулевая гипотеза(H_0)`: user_score_Xbox  = user_score_PC- Средние пользовательские рейтинги платформ Xbox One и PC **одинаковые**
# * `Альтернативная гипотеза (H_a)`: user_score_Xbox ≠ user_score_PC- Средние пользовательские рейтинги платформ Xbox One и PC **разные**
#
# alpha = 0.05 - выберим данный уровень значимости (вероятный порог "необычности")
#
# **user_score_Xbox** - средний пользовательский рейтинг платформы Xbox One\
# **user_score_PC** -  средний пользовательский рейтинг платформы PC

# %%
# Сделаем срез данных использовав метод `query` выбрав определенную платформу для анализа, исключив выбросы. 
user_score_Xbox = games_update.query('platform == "XOne" & user_score > 0')['user_score']

user_score_PC = games_update.query('platform == "PC" & user_score > 0')['user_score']
 
results = st.ttest_ind(
   user_score_Xbox, 
   user_score_PC, equal_var = False) # results = вызов метода для проверки гипотезы
 
alpha = .05 # alpha уровнь значимости
 
print(results.pvalue) # вывод значения p-value на экран 

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")# условный оператор с выводом строки с ответом
# Out:
# 0.16174359801784308
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Найдем дисперссию двух генеральных совокупностей
#
# Данные не равны, возможно ее не нужно искать в учебных целях :-)

# %%
a = np.var(user_score_Xbox)
b = np.var(user_score_PC)
print(np.average(a))
print(np.average(b))
# Out:
# 1.8965188383045533
# 2.9913239064252517

# %% [markdown]
# Перепровека: Посчитаем пользовательские рейтинги платформ Xbox One и PC

# %%
user_score_Xbox.mean()
# Out:
# 6.52142857142857

# %%
user_score_PC.mean()
# Out:
# 6.2803797468354405

# %% [markdown]
# Построим гистограмму распределения среднего пользовательского рейтинга платформ Xbox One и PC

# %%
games_update.query('platform == ["XOne","PC"] & user_score > 0').groupby('platform')['user_score']\
                                                             .plot(kind='hist', bins=20, alpha=0.5)
plt.legend(["XOne","PC"])
plt.xlabel('Оценка пользователей')
plt.ylabel('Объем продаж')
plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span> Вероятность *p-value* высока и равна 96%, что говорит о том, что нулевая гипотеза верна и значима. Кроме этого, данные математического расчета также это подтвердили. На гистограмме видно, многочисленное совпадение оценки пользователей двух платформ.

# %% [markdown]
# #### Проверка гипотезы №2: "Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные"

# %% [markdown]
# <span class="girk">Формулировка гипотез:</span>
#
# * `Нулевая гипотеза(H_0)`: user_score_Action  = user_score_Sports- Средние пользовательские рейтинги жанров Action и Sports **одинаковые**
# * `Альтернативная гипотеза (H_a)`: user_score_Action ≠ user_score_Sports- Средние пользовательские рейтинги жанров Action и Sports **разные**\
#
# alpha = 0.05- выберим данный уровень значимости (вероятный порог "необычности")
#
# **user_score_Action** - средний пользовательский рейтинг жанра Action (англ. «действие», экшен-игры)\
# **user_score_Sports** -  средний пользовательский рейтинг жанра Sports (англ. «спортивные соревнования»)

# %%
user_score_Action = games_update.query('genre == "Action" & user_score > 0')['user_score']

user_score_Sports = games_update.query('genre == "Sports" & user_score > 0')['user_score']
 
results = st.ttest_ind(
   user_score_Action, 
   user_score_Sports, equal_var = False) # results = вызов метода для проверки гипотезы
 
alpha = .05 # alpha уровнь значимости
 
print(results.pvalue) # вывод значения p-value на экран 

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")# условный оператор с выводом строки с ответом
# Out:
# 1.3883444596405356e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# Перепровека: Посчитаем средние пользовательские рейтинги жанров Action и Sports

# %%
user_score_Action.mean()
# Out:
# 6.837500000000005

# %%
user_score_Sports.mean()
# Out:
# 5.238124999999999

# %% [markdown]
# Построим гистограмму распределения среднего пользовательского рестинга жанров Action и Sports

# %%
games_update.query('genre == ["Action","Sports"] & user_score > 0').groupby('genre')['user_score']\
                                                             .plot(kind='hist', bins=20, alpha=0.5)
plt.legend(['Action','Sports'])
plt.xlabel('Оценка пользователей')
plt.ylabel('Объем продаж')
plt.show()

# %% [markdown]
# <span class="mark">**Наблюдение:**</span>  Получив крайне маленькое значение p-value, мы отвергли Нулевую гипотезу. Таким образом, у нас практически нет вероятности получить одинаково средние рейнтинги по двум жанрам. Перепроверка математическим путем и визуализация гистограммы нам это тоже показала.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# <div style="border:solid gray 2px; padding: 20px">
#
# Изучив данные из открытых источников, в котором содержалось 16715 строк и 11 столбцов о продажах игр, оценки пользователей и экспертов, жанры и платформы, нам нужно было выявить определяющие успешность игры закономерности.
#
# Предже, чем приступить к исследовательской работе, необходимо было сделать предобработку данных, а именно: привести в соответствие типы данных, обработать пустые значения, заменить верхний регистр, на нижний, проверить дубликаты, обработать выбросы (анамалии).
#   Если в данных наблюдались пропуски, они заменялись на среднию или медианную величину в разрезе, но в большей части заполнялись заглушками (-999), тк медианными значениями заполнить невозможно по причине отсутствия 100% совпадения по признаку.
#
#   Согласно историческим данным, основной "бум" на рынке игр наблюдался с 1990 по 2009 гг, где количество выпускаемых игр увеличилось в 30 раз или на 3000%. Далее после 2009 года наблюдается спад выпуска игр, что могло быть связано с появлением взаимозаменяемой продукции (современные мобильные устройства и приложения), далее стремительное падение до конца 2016 года. Топ-6 вошли такие платформы, как PS2, X360, PS3, Wii, DS и PS.
#
#   Проанализировав жизненный цикл платформ, было выявлено следующее:
#  - средний жизненный цикл платформ в рамках 8 лет;
#  - основными сменяющими лидерами были PS, после него PS2 (PlayStation 2) и Wii;
#  - в категорию **прибыльной платформы**, по факторам длительности существования и спроса, можно отнести **платформы PlayStation**.
#  - **"первопроходцем"** в игровой индустрии стала **платформа DS**, которая вышла на рынок в 1985 и ушла с рынка в 2013 году.
#  -**"инноватором"**  стала **платформа PS2 (PlayStation 2)**, которая занимала лидирующие позиции с 2000 по 2004 гг. и послужила мощным толчком в индустрии ирг, после чего пришло на рынок много играков. После 2004 до 2011 наблюдается спад и пониженный спрос.
#     - максимальный годовой объем продаж в диапозоне 1-1.5 млн.копий показали такие платформы, как Х360, PS4, ХOne и WiiU;
#
# Посмотрев на корреляцию между оценкой пользователей, оценкой критиков и продажами, прямой зависимости не обнаружено. Согласно Шкале Чеддока, коэффициент корреляции находиться в диапозоне **0.12-0.17** определим, как **"слабая"** связь. Есть предположение, что данные оценки, в тот период времени, не были широко офишированны в СМИ и в общем доступе не находились. Возможно данные собирались только для личного пользования компаниями и не влияли на выбор потребителей.
#     Наиболее прибыльными и популятными жанрами стали Action, Shooter, Role-Playing и Sports.
#
# Если говорить про портрет потребилеля, то стоит отметить, что предпочтения пользователей в Северной Америке и Европе практически совпали по популярности одних и тех же платформ(PS4, PS3, Х360, XOne и 3DS), жанров(action, shooler, sports, role-playing и misc) и рейтингов(«Для взрослых» от 17 лет и «Для всех"), что нельзя сказать про Японию, которая предпочитает такие платформы, как(3DS, PS4), жанры(Role-Playing, Action) и рейтинг( «Для всех» и «Подросткам» от 13 лет).
#
# **`После проведенной работы, можно сделать следующее заключение:`**
# продажа игр четко имеет зависимость от территориальной принадлежности пользователей и тех платформ, которые в данном регионе наиболее популярны.\
#     Для рынка Азии - это будет платформа 3DS с типами жанров ролевые игры и экшен. \
#     Для западного рынка больше подойдут продажи игр с платформами PS4 с жанрами экшен и игры с огнестрельным оружием.
#
# **Рекомендации:**
#
# При планировании продаж игр, следует определиться с рынком, на котором магазин, хотел бы сконцентрироваться, так как для каждого региона свой портрет пользователя.
#
# На планируемый
#  год следует обратить внимание на игры для следующих платформ:
#
# PS4
# XOne
# 3DS
# WiiU
# Наиболее перспективными жанрами игр являются:
#
# Shooter
# Sports
# Platform
# Role-Playing
# Action
# Для пользователей Северной Америки и Европы наиболее перспективными играми будут являться игры для PS4 в жанрах Shooter и Sports.
#
# Для жителей Японии, не смотря на постепенное снижение спроса, актуальными остаются игры для 3DS в жанре Role-Playing. При выборе игр пользоватетели больше ориентируются на оценки критиков, чем на пользовательские рейтинги.
#
# </div>
